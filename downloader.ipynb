# %%
import os, re, sys, arxiv, csv

def fix_title(title: str) -> str:
    return re.sub(r'[<>:"/\\|?*]', "_", re.sub(r"\s*\n+\s*", " ", title))

def paper_to_filename(paper: arxiv.Result) -> str:
    author_str = str(paper.authors[0]) + " et al." * (len(paper.authors) > 1)
    return f"{author_str} - {fix_title(paper.title)}.pdf"

def parse_line(line: str):
    m = re.match(r".*(?P<paper_id>\d{4}\.\d{4,6}(v\d+)?)(\.pdf)?$", line)
    return m.group("paper_id") if m is not None else None

# %%
with open("deepmind_RL_research.csv", 'r') as file:
    csvreader = csv.reader(file)
    paper_ids = [parse_line(row[0]) for row in csvreader]
    paper_ids = [x for x in paper_ids if x is not None]
    papers = arxiv.Search(id_list=paper_ids).results()

    # print(len(paper_ids))
    for paper, paper_id in zip(papers, paper_ids):
        print(f"PAPER {paper}")
        src_filename = f"{paper_id}.pdf"
        dst_filename = paper_to_filename(paper)
        # print("DST FILE dst_filename)
        if os.path.exists(dst_filename):
            print(f"[TargetExists] {dst_filename}")
        elif os.path.exists(src_filename):
            print(f"[Rename] {src_filename}")
            os.rename(src_filename, dst_filename)
        else:
            print("[Download]")
            paper.download_pdf(filename=dst_filename)
        print(f"file:    {dst_filename}")
        print(f"url:     {paper.entry_id}")
        print(f"authors: {[str(x) for x in paper.authors]}")
        print(f"title:   {paper.title}\n")
# Out:
# PAPER http://arxiv.org/abs/2302.06083v1
# [Download]
# file:    Samuel Allen Alexander et al. - Universal Agent Mixtures and the Geometry of Intelligence.pdf
# url:     http://arxiv.org/abs/2302.06083v1
# authors: ['Samuel Allen Alexander', 'David Quarel', 'Len Du', 'Marcus Hutter']
# title:   Universal Agent Mixtures and the Geometry of Intelligence
#
# PAPER http://arxiv.org/abs/2302.04693v1
# [Download]
# file:    Akhil Bagaria et al. - Scaling Goal-based Exploration via Pruning Proto-goals.pdf
# url:     http://arxiv.org/abs/2302.04693v1
# authors: ['Akhil Bagaria', 'Ray Jiang', 'Ramana Kumar', 'Tom Schaul']
# title:   Scaling Goal-based Exploration via Pruning Proto-goals
#
# PAPER http://arxiv.org/abs/2303.04012v1
# [Download]
# file:    Simon Schmitt et al. - Exploration via Epistemic Value Estimation.pdf
# url:     http://arxiv.org/abs/2303.04012v1
# authors: ['Simon Schmitt', 'John Shawe-Taylor', 'Hado van Hasselt']
# title:   Exploration via Epistemic Value Estimation
#
# PAPER http://arxiv.org/abs/2301.12507v2
# [Download]
# file:    Theodore Sumers et al. - Distilling Internet-Scale Vision-Language Models into Embodied Agents.pdf
# url:     http://arxiv.org/abs/2301.12507v2
# authors: ['Theodore Sumers', 'Kenneth Marino', 'Arun Ahuja', 'Rob Fergus', 'Ishita Dasgupta']
# title:   Distilling Internet-Scale Vision-Language Models into Embodied Agents
#
# PAPER http://arxiv.org/abs/2209.14414v1
# [Download]
# file:    Daniil Tiapkin et al. - Optimistic Posterior Sampling for Reinforcement Learning with Few Samples and Tight Guarantees.pdf
# url:     http://arxiv.org/abs/2209.14414v1
# authors: ['Daniil Tiapkin', 'Denis Belomestny', 'Daniele Calandriello', 'Eric Moulines', 'Remi Munos', 'Alexey Naumov', 'Mark Rowland', 'Michal Valko', 'Pierre Menard']
# title:   Optimistic Posterior Sampling for Reinforcement Learning with Few Samples and Tight Guarantees
#
# PAPER http://arxiv.org/abs/2204.08957v1
# [Download]
# file:    Jongmin Lee et al. - COptiDICE_ Offline Constrained Reinforcement Learning via Stationary Distribution Correction Estimation.pdf
# url:     http://arxiv.org/abs/2204.08957v1
# authors: ['Jongmin Lee', 'Cosmin Paduraru', 'Daniel J. Mankowitz', 'Nicolas Heess', 'Doina Precup', 'Kee-Eung Kim', 'Arthur Guez']
# title:   COptiDICE: Offline Constrained Reinforcement Learning via Stationary Distribution Correction Estimation
#
# PAPER http://arxiv.org/abs/2209.08112v1
# [Download]
# file:    William Wong et al. - Optimizing Industrial HVAC Systems with Hierarchical Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/2209.08112v1
# authors: ['William Wong', 'Praneet Dutta', 'Octavian Voicu', 'Yuri Chervonyi', 'Cosmin Paduraru', 'Jerry Luo']
# title:   Optimizing Industrial HVAC Systems with Hierarchical Reinforcement Learning
#
# PAPER http://arxiv.org/abs/2207.13131v1
# [Download]
# file:    Yuri Chervonyi et al. - Semi-analytical Industrial Cooling System Model for Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/2207.13131v1
# authors: ['Yuri Chervonyi', 'Praneet Dutta', 'Piotr Trochim', 'Octavian Voicu', 'Cosmin Paduraru', 'Crystal Qian', 'Emre Karagozler', 'Jared Quincy Davis', 'Richard Chippendale', 'Gautam Bajaj', 'Sims Witherspoon', 'Jerry Luo']
# title:   Semi-analytical Industrial Cooling System Model for Reinforcement Learning
#
# PAPER http://arxiv.org/abs/2206.08736v1
# [Download]
# file:    Shantanu Thakoor et al. - Generalised Policy Improvement with Geometric Policy Composition.pdf
# url:     http://arxiv.org/abs/2206.08736v1
# authors: ['Shantanu Thakoor', 'Mark Rowland', 'Diana Borsa', 'Will Dabney', 'Rémi Munos', 'André Barreto']
# title:   Generalised Policy Improvement with Geometric Policy Composition
#
# PAPER http://arxiv.org/abs/2205.07704v2
# [Download]
# file:    Daniil Tiapkin et al. - From Dirichlet to Rubin_ Optimistic Exploration in RL without Bonuses.pdf
# url:     http://arxiv.org/abs/2205.07704v2
# authors: ['Daniil Tiapkin', 'Denis Belomestny', 'Eric Moulines', 'Alexey Naumov', 'Sergey Samsonov', 'Yunhao Tang', 'Michal Valko', 'Pierre Menard']
# title:   From Dirichlet to Rubin: Optimistic Exploration in RL without Bonuses
#
# PAPER http://arxiv.org/abs/2209.06356v2
# [Download]
# file:    Augustine N. Mavor-Parker et al. - A Simple Approach for State-Action Abstraction using a Learned MDP Homomorphism.pdf
# url:     http://arxiv.org/abs/2209.06356v2
# authors: ['Augustine N. Mavor-Parker', 'Matthew J. Sargent', 'Andrea Banino', 'Lewis D. Griffin', 'Caswell Barry']
# title:   A Simple Approach for State-Action Abstraction using a Learned MDP Homomorphism
#
# PAPER http://arxiv.org/abs/2206.01192v1
# [Download]
# file:    Marcus Hutter et al. - Uniqueness and Complexity of Inverse MDP Models.pdf
# url:     http://arxiv.org/abs/2206.01192v1
# authors: ['Marcus Hutter', 'Steven Hansen']
# title:   Uniqueness and Complexity of Inverse MDP Models
#
# PAPER http://arxiv.org/abs/2106.10251v4
# [Download]
# file:    Ksenia Konyushkova et al. - Active Offline Policy Selection.pdf
# url:     http://arxiv.org/abs/2106.10251v4
# authors: ['Ksenia Konyushkova', 'Yutian Chen', 'Tom Le Paine', 'Caglar Gulcehre', 'Cosmin Paduraru', 'Daniel J Mankowitz', 'Misha Denil', 'Nando de Freitas']
# title:   Active Offline Policy Selection
#
# PAPER http://arxiv.org/abs/2203.16177v1
# [Download]
# file:    Yunhao Tang et al. - Marginalized Operators for Off-policy Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/2203.16177v1
# authors: ['Yunhao Tang', 'Mark Rowland', 'Rémi Munos', 'Michal Valko']
# title:   Marginalized Operators for Off-policy Reinforcement Learning
#
# PAPER http://arxiv.org/abs/2111.12045v2
# [Download]
# file:    Jean Tarbouriech et al. - Adaptive Multi-Goal Exploration.pdf
# url:     http://arxiv.org/abs/2111.12045v2
# authors: ['Jean Tarbouriech', 'Omar Darwiche Domingues', 'Pierre Ménard', 'Matteo Pirotta', 'Michal Valko', 'Alessandro Lazaric']
# title:   Adaptive Multi-Goal Exploration
#
# PAPER http://arxiv.org/abs/2203.12592v4
# [Download]
# file:    Rob Brekelmans et al. - Your Policy Regularizer is Secretly an Adversary.pdf
# url:     http://arxiv.org/abs/2203.12592v4
# authors: ['Rob Brekelmans', 'Tim Genewein', 'Jordi Grau-Moya', 'Grégoire Delétang', 'Markus Kunesch', 'Shane Legg', 'Pedro Ortega']
# title:   Your Policy Regularizer is Secretly an Adversary
#
# PAPER http://arxiv.org/abs/2111.08350v2
# [Download]
# file:    Paul Muller et al. - Learning Equilibria in Mean-Field Games_ Introducing Mean-Field PSRO.pdf
# url:     http://arxiv.org/abs/2111.08350v2
# authors: ['Paul Muller', 'Mark Rowland', 'Romuald Elie', 'Georgios Piliouras', 'Julien Perolat', 'Mathieu Lauriere', 'Raphael Marinier', 'Olivier Pietquin', 'Karl Tuyls']
# title:   Learning Equilibria in Mean-Field Games: Introducing Mean-Field PSRO
#
# PAPER http://arxiv.org/abs/2102.06924v2
# [Download]
# file:    Lior Shani et al. - Online Apprenticeship Learning.pdf
# url:     http://arxiv.org/abs/2102.06924v2
# authors: ['Lior Shani', 'Tom Zahavy', 'Shie Mannor']
# title:   Online Apprenticeship Learning
#
# PAPER http://arxiv.org/abs/2201.06468v2
# [Download]
# file:    Simon Schmitt et al. - Chaining Value Functions for Off-Policy Learning.pdf
# url:     http://arxiv.org/abs/2201.06468v2
# authors: ['Simon Schmitt', 'John Shawe-Taylor', 'Hado van Hasselt']
# title:   Chaining Value Functions for Off-Policy Learning
#
# PAPER http://arxiv.org/abs/2112.07774v2
# [Download]
# file:    Dylan J. A. Brenneis et al. - Assessing Human Interaction in Virtual Reality With Continually Learning Prediction Agents Based on Reinforcement Learning Algorithms_ A Pilot Study.pdf
# url:     http://arxiv.org/abs/2112.07774v2
# authors: ['Dylan J. A. Brenneis', 'Adam S. Parker', 'Michael Bradley Johanson', 'Andrew Butcher', 'Elnaz Davoodi', 'Leslie Acker', 'Matthew M. Botvinick', 'Joseph Modayil', 'Adam White', 'Patrick M. Pilarski']
# title:   Assessing Human Interaction in Virtual Reality With Continually Learning Prediction Agents Based on Reinforcement Learning Algorithms: A Pilot Study
#
# PAPER http://arxiv.org/abs/2112.04153v3
# [Download]
# file:    Angelos Filos et al. - Model-Value Inconsistency as a Signal for Epistemic Uncertainty.pdf
# url:     http://arxiv.org/abs/2112.04153v3
# authors: ['Angelos Filos', 'Eszter Vértes', 'Zita Marinho', 'Gregory Farquhar', 'Diana Borsa', 'Abram Friesen', 'Feryal Behbahani', 'Tom Schaul', 'André Barreto', 'Simon Osindero']
# title:   Model-Value Inconsistency as a Signal for Epistemic Uncertainty
#
# PAPER http://arxiv.org/abs/2110.14020v1
# [Download]
# file:    Georg Ostrovski et al. - The Difficulty of Passive Learning in Deep Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/2110.14020v1
# authors: ['Georg Ostrovski', 'Pablo Samuel Castro', 'Will Dabney']
# title:   The Difficulty of Passive Learning in Deep Reinforcement Learning
#
# PAPER http://arxiv.org/abs/2105.14039v3
# [Download]
# file:    Andrew Kyle Lampinen et al. - Towards mental time travel_ a hierarchical memory for reinforcement learning agents.pdf
# url:     http://arxiv.org/abs/2105.14039v3
# authors: ['Andrew Kyle Lampinen', 'Stephanie C. Y. Chan', 'Andrea Banino', 'Felix Hill']
# title:   Towards mental time travel: a hierarchical memory for reinforcement learning agents
#
# PAPER http://arxiv.org/abs/2108.03213v1
# [Download]
# file:    Khimya Khetarpal et al. - Temporally Abstract Partial Models.pdf
# url:     http://arxiv.org/abs/2108.03213v1
# authors: ['Khimya Khetarpal', 'Zafarali Ahmed', 'Gheorghe Comanici', 'Doina Precup']
# title:   Temporally Abstract Partial Models
#
# PAPER http://arxiv.org/abs/2004.05599v3
# [Download]
# file:    Omar Darwiche Domingues et al. - Kernel-Based Reinforcement Learning_ A Finite-Time Analysis.pdf
# url:     http://arxiv.org/abs/2004.05599v3
# authors: ['Omar Darwiche Domingues', 'Pierre Ménard', 'Matteo Pirotta', 'Emilie Kaufmann', 'Michal Valko']
# title:   Kernel-Based Reinforcement Learning: A Finite-Time Analysis
#
# PAPER http://arxiv.org/abs/2106.06170v2
# [Download]
# file:    Yunhao Tang et al. - Taylor Expansion of Discount Factors.pdf
# url:     http://arxiv.org/abs/2106.06170v2
# authors: ['Yunhao Tang', 'Mark Rowland', 'Rémi Munos', 'Michal Valko']
# title:   Taylor Expansion of Discount Factors
#
# PAPER http://arxiv.org/abs/2102.12560v2
# [Download]
# file:    Angelos Filos et al. - PsiPhi-Learning_ Reinforcement Learning with Demonstrations using Successor Features and Inverse Temporal Difference Learning.pdf
# url:     http://arxiv.org/abs/2102.12560v2
# authors: ['Angelos Filos', 'Clare Lyle', 'Yarin Gal', 'Sergey Levine', 'Natasha Jaques', 'Gregory Farquhar']
# title:   PsiPhi-Learning: Reinforcement Learning with Demonstrations using Successor Features and Inverse Temporal Difference Learning
#
# PAPER http://arxiv.org/abs/2103.00107v1
# [Download]
# file:    Tadashi Kozuno et al. - Revisiting Peng's Q($λ$) for Modern Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/2103.00107v1
# authors: ['Tadashi Kozuno', 'Yunhao Tang', 'Mark Rowland', 'Rémi Munos', 'Steven Kapturowski', 'Will Dabney', 'Michal Valko', 'David Abel']
# title:   Revisiting Peng's Q($λ$) for Modern Reinforcement Learning
#
# PAPER http://arxiv.org/abs/2106.13125v2
# [Download]
# file:    Yunhao Tang et al. - Unifying Gradient Estimators for Meta-Reinforcement Learning via Off-Policy Evaluation.pdf
# url:     http://arxiv.org/abs/2106.13125v2
# authors: ['Yunhao Tang', 'Tadashi Kozuno', 'Mark Rowland', 'Rémi Munos', 'Michal Valko']
# title:   Unifying Gradient Estimators for Meta-Reinforcement Learning via Off-Policy Evaluation
#
# PAPER http://arxiv.org/abs/2106.06279v1
# [Download]
# file:    Tadashi Kozuno et al. - Model-Free Learning for Two-Player Zero-Sum Partially Observable Markov Games with Perfect Recall.pdf
# url:     http://arxiv.org/abs/2106.06279v1
# authors: ['Tadashi Kozuno', 'Pierre Ménard', 'Rémi Munos', 'Michal Valko']
# title:   Model-Free Learning for Two-Player Zero-Sum Partially Observable Markov Games with Perfect Recall
#
# PAPER http://arxiv.org/abs/2011.01758v2
# [Download]
# file:    Markus Wulfmeier et al. - Representation Matters_ Improving Perception and Exploration for Robotics.pdf
# url:     http://arxiv.org/abs/2011.01758v2
# authors: ['Markus Wulfmeier', 'Arunkumar Byravan', 'Tim Hertweck', 'Irina Higgins', 'Ankush Gupta', 'Tejas Kulkarni', 'Malcolm Reynolds', 'Denis Teplyashin', 'Roland Hafner', 'Thomas Lampe', 'Martin Riedmiller']
# title:   Representation Matters: Improving Perception and Exploration for Robotics
#
# PAPER http://arxiv.org/abs/2105.05347v1
# [Download]
# file:    Tom Schaul et al. - Return-based Scaling_ Yet Another Normalisation Trick for Deep RL.pdf
# url:     http://arxiv.org/abs/2105.05347v1
# authors: ['Tom Schaul', 'Georg Ostrovski', 'Iurii Kemaev', 'Diana Borsa']
# title:   Return-based Scaling: Yet Another Normalisation Trick for Deep RL
#
# PAPER http://arxiv.org/abs/2104.11186v2
# [Download]
# file:    Jean Tarbouriech et al. - Stochastic Shortest Path_ Minimax, Parameter-Free and Towards Horizon-Free Regret.pdf
# url:     http://arxiv.org/abs/2104.11186v2
# authors: ['Jean Tarbouriech', 'Runlong Zhou', 'Simon S. Du', 'Matteo Pirotta', 'Michal Valko', 'Alessandro Lazaric']
# title:   Stochastic Shortest Path: Minimax, Parameter-Free and Towards Horizon-Free Regret
#
# PAPER http://arxiv.org/abs/2102.13089v1
# [Download]
# file:    Clare Lyle et al. - On The Effect of Auxiliary Tasks on Representation Dynamics.pdf
# url:     http://arxiv.org/abs/2102.13089v1
# authors: ['Clare Lyle', 'Mark Rowland', 'Georg Ostrovski', 'Will Dabney']
# title:   On The Effect of Auxiliary Tasks on Representation Dynamics
#
# PAPER http://arxiv.org/abs/2103.01312v2
# [Download]
# file:    Pierre Menard et al. - UCB Momentum Q-learning_ Correcting the bias without forgetting.pdf
# url:     http://arxiv.org/abs/2103.01312v2
# authors: ['Pierre Menard', 'Omar Darwiche Domingues', 'Xuedong Shang', 'Michal Valko']
# title:   UCB Momentum Q-learning: Correcting the bias without forgetting
#
# PAPER http://arxiv.org/abs/2007.05078v2
# [Download]
# file:    Omar Darwiche Domingues et al. - A Kernel-Based Approach to Non-Stationary Reinforcement Learning in Metric Spaces.pdf
# url:     http://arxiv.org/abs/2007.05078v2
# authors: ['Omar Darwiche Domingues', 'Pierre Ménard', 'Matteo Pirotta', 'Emilie Kaufmann', 'Michal Valko']
# title:   A Kernel-Based Approach to Non-Stationary Reinforcement Learning in Metric Spaces
#
# PAPER http://arxiv.org/abs/2010.03531v1
# [Download]
# file:    Omar Darwiche Domingues et al. - Episodic Reinforcement Learning in Finite MDPs_ Minimax Lower Bounds Revisited.pdf
# url:     http://arxiv.org/abs/2010.03531v1
# authors: ['Omar Darwiche Domingues', 'Pierre Ménard', 'Emilie Kaufmann', 'Michal Valko']
# title:   Episodic Reinforcement Learning in Finite MDPs: Minimax Lower Bounds Revisited
#
# PAPER http://arxiv.org/abs/2006.06294v2
# [Download]
# file:    Emilie Kaufmann et al. - Adaptive Reward-Free Exploration.pdf
# url:     http://arxiv.org/abs/2006.06294v2
# authors: ['Emilie Kaufmann', 'Pierre Ménard', 'Omar Darwiche Domingues', 'Anders Jonsson', 'Edouard Leurent', 'Michal Valko']
# title:   Adaptive Reward-Free Exploration
#
# PAPER http://arxiv.org/abs/2010.07877v1
# [Download]
# file:    Victoria Krakovna et al. - Avoiding Side Effects By Considering Future Tasks.pdf
# url:     http://arxiv.org/abs/2010.07877v1
# authors: ['Victoria Krakovna', 'Laurent Orseau', 'Richard Ngo', 'Miljan Martic', 'Shane Legg']
# title:   Avoiding Side Effects By Considering Future Tasks
#
# PAPER http://arxiv.org/abs/2010.02255v2
# [Download]
# file:    Sebastian Flennerhag et al. - Temporal Difference Uncertainties as a Signal for Exploration.pdf
# url:     http://arxiv.org/abs/2010.02255v2
# authors: ['Sebastian Flennerhag', 'Jane X. Wang', 'Pablo Sprechmann', 'Francesco Visin', 'Alexandre Galashov', 'Steven Kapturowski', 'Diana L. Borsa', 'Nicolas Heess', 'Andre Barreto', 'Razvan Pascanu']
# title:   Temporal Difference Uncertainties as a Signal for Exploration
#
# PAPER http://arxiv.org/abs/2010.02193v4
# [Download]
# file:    Danijar Hafner et al. - Mastering Atari with Discrete World Models.pdf
# url:     http://arxiv.org/abs/2010.02193v4
# authors: ['Danijar Hafner', 'Timothy Lillicrap', 'Mohammad Norouzi', 'Jimmy Ba']
# title:   Mastering Atari with Discrete World Models
#
# PAPER http://arxiv.org/abs/2010.01374v2
# [Download]
# file:    Gellért Weisz et al. - Exponential Lower Bounds for Planning in MDPs With Linearly-Realizable Optimal Action-Value Functions.pdf
# url:     http://arxiv.org/abs/2010.01374v2
# authors: ['Gellért Weisz', 'Philip Amortila', 'Csaba Szepesvári']
# title:   Exponential Lower Bounds for Planning in MDPs With Linearly-Realizable Optimal Action-Value Functions
#
# PAPER http://arxiv.org/abs/2009.14280v2
# [Download]
# file:    Yusheng Jiao et al. - Learning to swim in potential flow.pdf
# url:     http://arxiv.org/abs/2009.14280v2
# authors: ['Yusheng Jiao', 'Feng Ling', 'Sina Heydari', 'Nicolas Heess', 'Josh Merel', 'Eva Kanso']
# title:   Learning to swim in potential flow
#
# PAPER http://arxiv.org/abs/2009.04374v2
# [Download]
# file:    Nenad Tomašev et al. - Assessing Game Balance with AlphaZero_ Exploring Alternative Rule Sets in Chess.pdf
# url:     http://arxiv.org/abs/2009.04374v2
# authors: ['Nenad Tomašev', 'Ulrich Paquet', 'Demis Hassabis', 'Vladimir Kramnik']
# title:   Assessing Game Balance with AlphaZero: Exploring Alternative Rule Sets in Chess
#
# PAPER http://arxiv.org/abs/2009.04875v2
# [Download]
# file:    Alexandre Galashov et al. - Importance Weighted Policy Learning and Adaptation.pdf
# url:     http://arxiv.org/abs/2009.04875v2
# authors: ['Alexandre Galashov', 'Jakub Sygnowski', 'Guillaume Desjardins', 'Jan Humplik', 'Leonard Hasenclever', 'Rae Jeong', 'Yee Whye Teh', 'Nicolas Heess']
# title:   Importance Weighted Policy Learning and Adaptation
#
# PAPER http://arxiv.org/abs/2009.01791v3
# [Download]
# file:    Danijar Hafner et al. - Action and Perception as Divergence Minimization.pdf
# url:     http://arxiv.org/abs/2009.01791v3
# authors: ['Danijar Hafner', 'Pedro A. Ortega', 'Jimmy Ba', 'Thomas Parr', 'Karl Friston', 'Nicolas Heess']
# title:   Action and Perception as Divergence Minimization
#
# PAPER http://arxiv.org/abs/2008.12234v1
# [Download]
# file:    Audrūnas Gruslys et al. - The Advantage Regret-Matching Actor-Critic.pdf
# url:     http://arxiv.org/abs/2008.12234v1
# authors: ['Audrūnas Gruslys', 'Marc Lanctot', 'Rémi Munos', 'Finbarr Timbers', 'Martin Schmid', 'Julien Perolat', 'Dustin Morrill', 'Vinicius Zambaldi', 'Jean-Baptiste Lespiau', 'John Schultz', 'Mohammad Gheshlaghi Azar', 'Michael Bowling', 'Karl Tuyls']
# title:   The Advantage Regret-Matching Actor-Critic
#
# PAPER http://arxiv.org/abs/2008.07353v1
# [Download]
# file:    Wenlong Mou et al. - On the Sample Complexity of Reinforcement Learning with Policy Space Generalization.pdf
# url:     http://arxiv.org/abs/2008.07353v1
# authors: ['Wenlong Mou', 'Zheng Wen', 'Xi Chen']
# title:   On the Sample Complexity of Reinforcement Learning with Policy Space Generalization
#
# PAPER http://arxiv.org/abs/2007.15788v2
# [Download]
# file:    Jie Zhou et al. - Stochastic Low-rank Tensor Bandits for Multi-dimensional Online Decision Making.pdf
# url:     http://arxiv.org/abs/2007.15788v2
# authors: ['Jie Zhou', 'Botao Hao', 'Zheng Wen', 'Jingfei Zhang', 'Will Wei Sun']
# title:   Stochastic Low-rank Tensor Bandits for Multi-dimensional Online Decision Making
#
# PAPER http://arxiv.org/abs/2007.15588v2
# [Download]
# file:    Markus Wulfmeier et al. - Data-efficient Hindsight Off-policy Option Learning.pdf
# url:     http://arxiv.org/abs/2007.15588v2
# authors: ['Markus Wulfmeier', 'Dushyant Rao', 'Roland Hafner', 'Thomas Lampe', 'Abbas Abdolmaleki', 'Tim Hertweck', 'Michael Neunert', 'Dhruva Tirumala', 'Noah Siegel', 'Nicolas Heess', 'Martin Riedmiller']
# title:   Data-efficient Hindsight Off-policy Option Learning
#
# PAPER http://arxiv.org/abs/2007.12509v1
# [Download]
# file:    Jean-Bastien Grill et al. - Monte-Carlo Tree Search as Regularized Policy Optimization.pdf
# url:     http://arxiv.org/abs/2007.12509v1
# authors: ['Jean-Bastien Grill', 'Florent Altché', 'Yunhao Tang', 'Thomas Hubert', 'Michal Valko', 'Ioannis Antonoglou', 'Rémi Munos']
# title:   Monte-Carlo Tree Search as Regularized Policy Optimization
#
# PAPER http://arxiv.org/abs/2007.08794v3
# [Download]
# file:    Junhyuk Oh et al. - Discovering Reinforcement Learning Algorithms.pdf
# url:     http://arxiv.org/abs/2007.08794v3
# authors: ['Junhyuk Oh', 'Matteo Hessel', 'Wojciech M. Czarnecki', 'Zhongwen Xu', 'Hado van Hasselt', 'Satinder Singh', 'David Silver']
# title:   Discovering Reinforcement Learning Algorithms
#
# PAPER http://arxiv.org/abs/2007.09055v1
# [Download]
# file:    Tom Le Paine et al. - Hyperparameter Selection for Offline Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/2007.09055v1
# authors: ['Tom Le Paine', 'Cosmin Paduraru', 'Andrea Michi', 'Caglar Gulcehre', 'Konrad Zolna', 'Alexander Novikov', 'Ziyu Wang', 'Nando de Freitas']
# title:   Hyperparameter Selection for Offline Reinforcement Learning
#
# PAPER http://arxiv.org/abs/2007.06184v1
# [Download]
# file:    Roshan Shariff et al. - Efficient Planning in Large MDPs with Weak Linear Function Approximation.pdf
# url:     http://arxiv.org/abs/2007.06184v1
# authors: ['Roshan Shariff', 'Csaba Szepesvári']
# title:   Efficient Planning in Large MDPs with Weak Linear Function Approximation
#
# PAPER http://arxiv.org/abs/2007.04915v1
# [Download]
# file:    Tong Yu et al. - Influence Diagram Bandits_ Variational Thompson Sampling for Structured Bandit Problems.pdf
# url:     http://arxiv.org/abs/2007.04915v1
# authors: ['Tong Yu', 'Branislav Kveton', 'Zheng Wen', 'Ruiyi Zhang', 'Ole J. Mengshoel']
# title:   Influence Diagram Bandits: Variational Thompson Sampling for Structured Bandit Problems
#
# PAPER http://arxiv.org/abs/2007.00611v4
# [Download]
# file:    Sina Ghiassian et al. - Gradient Temporal-Difference Learning with Regularized Corrections.pdf
# url:     http://arxiv.org/abs/2007.00611v4
# authors: ['Sina Ghiassian', 'Andrew Patterson', 'Shivam Garg', 'Dhawal Gupta', 'Adam White', 'Martha White']
# title:   Gradient Temporal-Difference Learning with Regularized Corrections
#
# PAPER http://arxiv.org/abs/2007.03807v1
# [Download]
# file:    Vincent Liu et al. - Towards a practical measure of interference for reinforcement learning.pdf
# url:     http://arxiv.org/abs/2007.03807v1
# authors: ['Vincent Liu', 'Adam White', 'Hengshuai Yao', 'Martha White']
# title:   Towards a practical measure of interference for reinforcement learning
#
# PAPER http://arxiv.org/abs/2007.01839v2
# [Download]
# file:    Hado van Hasselt et al. - Expected Eligibility Traces.pdf
# url:     http://arxiv.org/abs/2007.01839v2
# authors: ['Hado van Hasselt', 'Sephora Madjiheurem', 'Matteo Hessel', 'David Silver', 'André Barreto', 'Diana Borsa']
# title:   Expected Eligibility Traces
#
# PAPER http://arxiv.org/abs/2006.12620v1
# [Download]
# file:    Nevena Lazic et al. - A maximum-entropy approach to off-policy evaluation in average-reward MDPs.pdf
# url:     http://arxiv.org/abs/2006.12620v1
# authors: ['Nevena Lazic', 'Dong Yin', 'Mehrdad Farajtabar', 'Nir Levine', 'Dilan Gorur', 'Chris Harris', 'Dale Schuurmans']
# title:   A maximum-entropy approach to off-policy evaluation in average-reward MDPs
#
# PAPER http://arxiv.org/abs/2006.04635v4
# [Download]
# file:    Thomas Anthony et al. - Learning to Play No-Press Diplomacy with Best Response Policy Iteration.pdf
# url:     http://arxiv.org/abs/2006.04635v4
# authors: ['Thomas Anthony', 'Tom Eccles', 'Andrea Tacchetti', 'János Kramár', 'Ian Gemp', 'Thomas C. Hudson', 'Nicolas Porcel', 'Marc Lanctot', 'Julien Pérolat', 'Richard Everett', 'Roman Werpachowski', 'Satinder Singh', 'Thore Graepel', 'Yoram Bachrach']
# title:   Learning to Play No-Press Diplomacy with Best Response Policy Iteration
#
# PAPER http://arxiv.org/abs/2006.08767v3
# [Download]
# file:    Borja G. León et al. - Systematic Generalisation through Task Temporal Logic and Deep Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/2006.08767v3
# authors: ['Borja G. León', 'Murray Shanahan', 'Francesco Belardinelli']
# title:   Systematic Generalisation through Task Temporal Logic and Deep Reinforcement Learning
#
# PAPER http://arxiv.org/abs/2006.05145v2
# [Download]
# file:    Brendan O'Donoghue et al. - Matrix games with bandit feedback.pdf
# url:     http://arxiv.org/abs/2006.05145v2
# authors: ["Brendan O'Donoghue", 'Tor Lattimore', 'Ian Osband']
# title:   Matrix games with bandit feedback
#
# PAPER http://arxiv.org/abs/2006.03662v3
# [Download]
# file:    Sam Ritter et al. - Rapid Task-Solving in Novel Environments.pdf
# url:     http://arxiv.org/abs/2006.03662v3
# authors: ['Sam Ritter', 'Ryan Faulkner', 'Laurent Sartran', 'Adam Santoro', 'Matt Botvinick', 'David Raposo']
# title:   Rapid Task-Solving in Novel Environments
#
# PAPER http://arxiv.org/abs/2006.02243v2
# [Download]
# file:    Will Dabney et al. - The Value-Improvement Path_ Towards Better Representations for Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/2006.02243v2
# authors: ['Will Dabney', 'André Barreto', 'Mark Rowland', 'Robert Dadashi', 'John Quan', 'Marc G. Bellemare', 'David Silver']
# title:   The Value-Improvement Path: Towards Better Representations for Reinforcement Learning
#
# PAPER http://arxiv.org/abs/2006.02419v2
# [Download]
# file:    Angeliki Lazaridou et al. - Emergent Multi-Agent Communication in the Deep Learning Era.pdf
# url:     http://arxiv.org/abs/2006.02419v2
# authors: ['Angeliki Lazaridou', 'Marco Baroni']
# title:   Emergent Multi-Agent Communication in the Deep Learning Era
#
# PAPER http://arxiv.org/abs/2006.01782v1
# [Download]
# file:    Will Dabney et al. - Temporally-Extended ε-Greedy Exploration.pdf
# url:     http://arxiv.org/abs/2006.01782v1
# authors: ['Will Dabney', 'Georg Ostrovski', 'André Barreto']
# title:   Temporally-Extended ε-Greedy Exploration
#
# PAPER http://arxiv.org/abs/2005.07513v1
# [Download]
# file:    Abbas Abdolmaleki et al. - A Distributional View on Multi-Objective Policy Optimization.pdf
# url:     http://arxiv.org/abs/2005.07513v1
# authors: ['Abbas Abdolmaleki', 'Sandy H. Huang', 'Leonard Hasenclever', 'Michael Neunert', 'H. Francis Song', 'Martina Zambelli', 'Murilo F. Martins', 'Nicolas Heess', 'Raia Hadsell', 'Martin Riedmiller']
# title:   A Distributional View on Multi-Objective Policy Optimization
#
# PAPER http://arxiv.org/abs/2005.06392v3
# [Download]
# file:    Jincheng Mei et al. - On the Global Convergence Rates of Softmax Policy Gradient Methods.pdf
# url:     http://arxiv.org/abs/2005.06392v3
# authors: ['Jincheng Mei', 'Chenjun Xiao', 'Csaba Szepesvari', 'Dale Schuurmans']
# title:   On the Global Convergence Rates of Softmax Policy Gradient Methods
#
# PAPER http://arxiv.org/abs/2005.07541v1
# [Download]
# file:    Tim Hertweck et al. - Simple Sensor Intentions for Exploration.pdf
# url:     http://arxiv.org/abs/2005.07541v1
# authors: ['Tim Hertweck', 'Martin Riedmiller', 'Michael Bloesch', 'Jost Tobias Springenberg', 'Noah Siegel', 'Markus Wulfmeier', 'Roland Hafner', 'Nicolas Heess']
# title:   Simple Sensor Intentions for Exploration
#
# PAPER http://arxiv.org/abs/2004.13654v1
# [Download]
# file:    Stuart Armstrong et al. - Pitfalls of learning a reward function online.pdf
# url:     http://arxiv.org/abs/2004.13654v1
# authors: ['Stuart Armstrong', 'Jan Leike', 'Laurent Orseau', 'Shane Legg']
# title:   Pitfalls of learning a reward function online
#
# PAPER http://arxiv.org/abs/2004.11410v1
# [Download]
# file:    Giambattista Parascandolo et al. - Divide-and-Conquer Monte Carlo Tree Search For Goal-Directed Planning.pdf
# url:     http://arxiv.org/abs/2004.11410v1
# authors: ['Giambattista Parascandolo', 'Lars Buesing', 'Josh Merel', 'Leonard Hasenclever', 'John Aslanides', 'Jessica B. Hamrick', 'Nicolas Heess', 'Alexander Neitz', 'Theophane Weber']
# title:   Divide-and-Conquer Monte Carlo Tree Search For Goal-Directed Planning
#
# PAPER http://arxiv.org/abs/2004.01097v2
# [Download]
# file:    Ivana Kajić et al. - Learning to cooperate_ Emergent communication in multi-agent navigation.pdf
# url:     http://arxiv.org/abs/2004.01097v2
# authors: ['Ivana Kajić', 'Eser Aygün', 'Doina Precup']
# title:   Learning to cooperate: Emergent communication in multi-agent navigation
#
# PAPER http://arxiv.org/abs/2003.14089v5
# [Download]
# file:    Nino Vieillard et al. - Leverage the Average_ an Analysis of KL Regularization in RL.pdf
# url:     http://arxiv.org/abs/2003.14089v5
# authors: ['Nino Vieillard', 'Tadashi Kozuno', 'Bruno Scherrer', 'Olivier Pietquin', 'Rémi Munos', 'Matthieu Geist']
# title:   Leverage the Average: an Analysis of KL Regularization in RL
#
# PAPER http://arxiv.org/abs/2003.13350v1
# [Download]
# file:    Adrià Puigdomènech Badia et al. - Agent57_ Outperforming the Atari Human Benchmark.pdf
# url:     http://arxiv.org/abs/2003.13350v1
# authors: ['Adrià Puigdomènech Badia', 'Bilal Piot', 'Steven Kapturowski', 'Pablo Sprechmann', 'Alex Vitvitskyi', 'Daniel Guo', 'Charles Blundell']
# title:   Agent57: Outperforming the Atari Human Benchmark
#
# PAPER http://arxiv.org/abs/2003.11881v2
# [Download]
# file:    Gabriel Dulac-Arnold et al. - An empirical investigation of the challenges of real-world reinforcement learning.pdf
# url:     http://arxiv.org/abs/2003.11881v2
# authors: ['Gabriel Dulac-Arnold', 'Nir Levine', 'Daniel J. Mankowitz', 'Jerry Li', 'Cosmin Paduraru', 'Sven Gowal', 'Todd Hester']
# title:   An empirical investigation of the challenges of real-world reinforcement learning
#
# PAPER http://arxiv.org/abs/2003.06259v1
# [Download]
# file:    Yunhao Tang et al. - Taylor Expansion Policy Optimization.pdf
# url:     http://arxiv.org/abs/2003.06259v1
# authors: ['Yunhao Tang', 'Michal Valko', 'Rémi Munos']
# title:   Taylor Expansion Policy Optimization
#
# PAPER http://arxiv.org/abs/2003.05012v4
# [Download]
# file:    Stephanie Milani et al. - Retrospective Analysis of the 2019 MineRL Competition on Sample Efficient Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/2003.05012v4
# authors: ['Stephanie Milani', 'Nicholay Topin', 'Brandon Houghton', 'William H. Guss', 'Sharada P. Mohanty', 'Keisuke Nakata', 'Oriol Vinyals', 'Noboru Sean Kuno']
# title:   Retrospective Analysis of the 2019 MineRL Competition on Sample Efficient Reinforcement Learning
#
# PAPER http://arxiv.org/abs/2002.11182v1
# [Download]
# file:    Johannes Kirschner et al. - Information Directed Sampling for Linear Partial Monitoring.pdf
# url:     http://arxiv.org/abs/2002.11182v1
# authors: ['Johannes Kirschner', 'Tor Lattimore', 'Andreas Krause']
# title:   Information Directed Sampling for Linear Partial Monitoring
#
# PAPER http://arxiv.org/abs/2002.08396v3
# [Download]
# file:    Noah Y. Siegel et al. - Keep Doing What Worked_ Behavioral Modelling Priors for Offline Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/2002.08396v3
# authors: ['Noah Y. Siegel', 'Jost Tobias Springenberg', 'Felix Berkenkamp', 'Abbas Abdolmaleki', 'Michael Neunert', 'Thomas Lampe', 'Roland Hafner', 'Nicolas Heess', 'Martin Riedmiller']
# title:   Keep Doing What Worked: Behavioral Modelling Priors for Offline Reinforcement Learning
#
# PAPER http://arxiv.org/abs/2002.08456v1
# [Download]
# file:    Julien Perolat et al. - From Poincaré Recurrence to Convergence in Imperfect Information Games_ Finding Equilibrium via Regularization.pdf
# url:     http://arxiv.org/abs/2002.08456v1
# authors: ['Julien Perolat', 'Remi Munos', 'Jean-Baptiste Lespiau', 'Shayegan Omidshafiei', 'Mark Rowland', 'Pedro Ortega', 'Neil Burch', 'Thomas Anthony', 'David Balduzzi', 'Bart De Vylder', 'Georgios Piliouras', 'Marc Lanctot', 'Karl Tuyls']
# title:   From Poincaré Recurrence to Convergence in Imperfect Information Games: Finding Equilibrium via Regularization
#
# PAPER http://arxiv.org/abs/2002.02325v2
# [Download]
# file:    Kevin R. McKee et al. - Social diversity and social preferences in mixed-motive reinforcement learning.pdf
# url:     http://arxiv.org/abs/2002.02325v2
# authors: ['Kevin R. McKee', 'Ian Gemp', 'Brian McWilliams', 'Edgar A. Duéñez-Guzmán', 'Edward Hughes', 'Joel Z. Leibo']
# title:   Social diversity and social preferences in mixed-motive reinforcement learning
#
# PAPER http://arxiv.org/abs/2002.04335v2
# [Download]
# file:    Eren Sezener et al. - Static and Dynamic Values of Computation in MCTS.pdf
# url:     http://arxiv.org/abs/2002.04335v2
# authors: ['Eren Sezener', 'Peter Dayan']
# title:   Static and Dynamic Values of Computation in MCTS
#
# PAPER http://arxiv.org/abs/2002.08329v2
# [Download]
# file:    Arthur Guez et al. - Value-driven Hindsight Modelling.pdf
# url:     http://arxiv.org/abs/2002.08329v2
# authors: ['Arthur Guez', 'Fabio Viola', 'Théophane Weber', 'Lars Buesing', 'Steven Kapturowski', 'Doina Precup', 'David Silver', 'Nicolas Heess']
# title:   Value-driven Hindsight Modelling
#
# PAPER http://arxiv.org/abs/2001.00805v3
# [Download]
# file:    Brendan O'Donoghue et al. - Making Sense of Reinforcement Learning and Probabilistic Inference.pdf
# url:     http://arxiv.org/abs/2001.00805v3
# authors: ["Brendan O'Donoghue", 'Ian Osband', 'Catalin Ionescu']
# title:   Making Sense of Reinforcement Learning and Probabilistic Inference
#
# PAPER http://arxiv.org/abs/1912.06910v1
# [Download]
# file:    Tom Schaul et al. - Adapting Behaviour for Learning Progress.pdf
# url:     http://arxiv.org/abs/1912.06910v1
# authors: ['Tom Schaul', 'Diana Borsa', 'David Ding', 'David Szepesvari', 'Georg Ostrovski', 'Will Dabney', 'Simon Osindero']
# title:   Adapting Behaviour for Learning Progress
#
# PAPER http://arxiv.org/abs/1912.05500v3
# [Download]
# file:    Zeyu Zheng et al. - What Can Learned Intrinsic Rewards Capture_.pdf
# url:     http://arxiv.org/abs/1912.05500v3
# authors: ['Zeyu Zheng', 'Junhyuk Oh', 'Matteo Hessel', 'Zhongwen Xu', 'Manuel Kroiss', 'Hado van Hasselt', 'David Silver', 'Satinder Singh']
# title:   What Can Learned Intrinsic Rewards Capture?
#
# PAPER http://arxiv.org/abs/1912.02807v2
# [Download]
# file:    Jessica B. Hamrick et al. - Combining Q-Learning and Search with Amortized Value Estimates.pdf
# url:     http://arxiv.org/abs/1912.02807v2
# authors: ['Jessica B. Hamrick', 'Victor Bapst', 'Alvaro Sanchez-Gonzalez', 'Tobias Pfaff', 'Theophane Weber', 'Lars Buesing', 'Peter W. Battaglia']
# title:   Combining Q-Learning and Search with Amortized Value Estimates
#
# PAPER http://arxiv.org/abs/1912.01603v3
# [Download]
# file:    Danijar Hafner et al. - Dream to Control_ Learning Behaviors by Latent Imagination.pdf
# url:     http://arxiv.org/abs/1912.01603v3
# authors: ['Danijar Hafner', 'Timothy Lillicrap', 'Jimmy Ba', 'Mohammad Norouzi']
# title:   Dream to Control: Learning Behaviors by Latent Imagination
#
# PAPER http://arxiv.org/abs/1911.08265v2
# [Download]
# file:    Julian Schrittwieser et al. - Mastering Atari, Go, Chess and Shogi by Planning with a Learned Model.pdf
# url:     http://arxiv.org/abs/1911.08265v2
# authors: ['Julian Schrittwieser', 'Ioannis Antonoglou', 'Thomas Hubert', 'Karen Simonyan', 'Laurent Sifre', 'Simon Schmitt', 'Arthur Guez', 'Edward Lockhart', 'Demis Hassabis', 'Thore Graepel', 'Timothy Lillicrap', 'David Silver']
# title:   Mastering Atari, Go, Chess and Shogi by Planning with a Learned Model
#
# PAPER http://arxiv.org/abs/1911.07676v2
# [Download]
# file:    Tor Lattimore et al. - Learning with Good Feature Representations in Bandits and in RL with a Generative Model.pdf
# url:     http://arxiv.org/abs/1911.07676v2
# authors: ['Tor Lattimore', 'Csaba Szepesvari', 'Gellert Weisz']
# title:   Learning with Good Feature Representations in Bandits and in RL with a Generative Model
#
# PAPER http://arxiv.org/abs/1911.01831v1
# [Download]
# file:    Jonas Degrave et al. - Quinoa_ a Q-function You Infer Normalized Over Actions.pdf
# url:     http://arxiv.org/abs/1911.01831v1
# authors: ['Jonas Degrave', 'Abbas Abdolmaleki', 'Jost Tobias Springenberg', 'Nicolas Heess', 'Martin Riedmiller']
# title:   Quinoa: a Q-function You Infer Normalized Over Actions
#
# PAPER http://arxiv.org/abs/1910.08446v1
# [Download]
# file:    Pratik Gajane et al. - Autonomous exploration for navigating in non-stationary CMPs.pdf
# url:     http://arxiv.org/abs/1910.08446v1
# authors: ['Pratik Gajane', 'Ronald Ortner', 'Peter Auer', 'Csaba Szepesvari']
# title:   Autonomous exploration for navigating in non-stationary CMPs
#
# PAPER http://arxiv.org/abs/1910.07478v1
# [Download]
# file:    Mark Rowland et al. - Adaptive Trade-Offs in Off-Policy Learning.pdf
# url:     http://arxiv.org/abs/1910.07478v1
# authors: ['Mark Rowland', 'Will Dabney', 'Rémi Munos']
# title:   Adaptive Trade-Offs in Off-Policy Learning
#
# PAPER http://arxiv.org/abs/1910.05876v1
# [Download]
# file:    Jonathan Lebensold et al. - Actor Critic with Differentially Private Critic.pdf
# url:     http://arxiv.org/abs/1910.05876v1
# authors: ['Jonathan Lebensold', 'William Hamilton', 'Borja Balle', 'Doina Precup']
# title:   Actor Critic with Differentially Private Critic
#
# PAPER http://arxiv.org/abs/1910.04142v1
# [Download]
# file:    Arunkumar Byravan et al. - Imagined Value Gradients_ Model-Based Policy Optimization with Transferable Latent Dynamics Models.pdf
# url:     http://arxiv.org/abs/1910.04142v1
# authors: ['Arunkumar Byravan', 'Jost Tobias Springenberg', 'Abbas Abdolmaleki', 'Roland Hafner', 'Michael Neunert', 'Thomas Lampe', 'Noah Siegel', 'Nicolas Heess', 'Martin Riedmiller']
# title:   Imagined Value Gradients: Model-Based Policy Optimization with Transferable Latent Dynamics Models
#
# PAPER http://arxiv.org/abs/1909.04607v1
# [Download]
# file:    Vivek Veeriah et al. - Discovery of Useful Questions as Auxiliary Tasks.pdf
# url:     http://arxiv.org/abs/1909.04607v1
# authors: ['Vivek Veeriah', 'Matteo Hessel', 'Zhongwen Xu', 'Richard Lewis', 'Janarthanan Rajendran', 'Junhyuk Oh', 'Hado van Hasselt', 'David Silver', 'Satinder Singh']
# title:   Discovery of Useful Questions as Auxiliary Tasks
#
# PAPER http://arxiv.org/abs/1908.09453v2
# [Download]
# file:    Marc Lanctot et al. - OpenSpiel_ A Framework for Reinforcement Learning in Games.pdf
# url:     http://arxiv.org/abs/1908.09453v2
# authors: ['Marc Lanctot', 'Edward Lockhart', 'Jean-Baptiste Lespiau', 'Vinicius Zambaldi', 'Satyaki Upadhyay', 'Julien Pérolat', 'Sriram Srinivasan', 'Finbarr Timbers', 'Karl Tuyls', 'Shayegan Omidshafiei', 'Daniel Hennes', 'Dustin Morrill', 'Paul Muller', 'Timo Ewalds', 'Ryan Faulkner', 'János Kramár', 'Bart De Vylder', 'Brennan Saeta', 'James Bradbury', 'David Ding', 'Sebastian Borgeaud', 'Matthew Lai', 'Julian Schrittwieser', 'Thomas Anthony', 'Edward Hughes', 'Ivo Danihelka', 'Jonah Ryan-Davis']
# title:   OpenSpiel: A Framework for Reinforcement Learning in Games
#
# PAPER http://arxiv.org/abs/1908.04734v3
# [Download]
# file:    Tom Everitt et al. - Reward Tampering Problems and Solutions in Reinforcement Learning_ A Causal Influence Diagram Perspective.pdf
# url:     http://arxiv.org/abs/1908.04734v3
# authors: ['Tom Everitt', 'Marcus Hutter']
# title:   Reward Tampering Problems and Solutions in Reinforcement Learning: A Causal Influence Diagram Perspective
#
# PAPER http://arxiv.org/abs/1908.03568v3
# [Download]
# file:    Ian Osband et al. - Behaviour Suite for Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/1908.03568v3
# authors: ['Ian Osband', 'Yotam Doron', 'Matteo Hessel', 'John Aslanides', 'Eren Sezener', 'Andre Saraiva', 'Katrina McKinney', 'Tor Lattimore', 'Csaba Szepesvari', 'Satinder Singh', 'Benjamin Van Roy', 'Richard Sutton', 'David Silver', 'Hado Van Hasselt']
# title:   Behaviour Suite for Reinforcement Learning
#
# PAPER http://arxiv.org/abs/1907.09633v1
# [Download]
# file:    Trevor Davis et al. - Low-Variance and Zero-Variance Baselines for Extensive-Form Games.pdf
# url:     http://arxiv.org/abs/1907.09633v1
# authors: ['Trevor Davis', 'Martin Schmid', 'Michael Bowling']
# title:   Low-Variance and Zero-Variance Baselines for Extensive-Form Games
#
# PAPER http://arxiv.org/abs/1906.01624v3
# [Download]
# file:    Alex Irpan et al. - Off-Policy Evaluation via Off-Policy Classification.pdf
# url:     http://arxiv.org/abs/1906.01624v3
# authors: ['Alex Irpan', 'Kanishka Rao', 'Konstantinos Bousmalis', 'Chris Harris', 'Julian Ibarz', 'Sergey Levine']
# title:   Off-Policy Evaluation via Off-Policy Classification
#
# PAPER http://arxiv.org/abs/1907.03687v1
# [Download]
# file:    Hado van Hasselt et al. - General non-linear Bellman equations.pdf
# url:     http://arxiv.org/abs/1907.03687v1
# authors: ['Hado van Hasselt', 'John Quan', 'Matteo Hessel', 'Zhongwen Xu', 'Diana Borsa', 'Andre Barreto']
# title:   General non-linear Bellman equations
#
# PAPER http://arxiv.org/abs/1907.02908v1
# [Download]
# file:    Matteo Hessel et al. - On Inductive Biases in Deep Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/1907.02908v1
# authors: ['Matteo Hessel', 'Hado van Hasselt', 'Joseph Modayil', 'David Silver']
# title:   On Inductive Biases in Deep Reinforcement Learning
#
# PAPER http://arxiv.org/abs/1907.02633v1
# [Download]
# file:    Romuald Elie et al. - Approximate Fictitious Play for Mean Field Games.pdf
# url:     http://arxiv.org/abs/1907.02633v1
# authors: ['Romuald Elie', 'Julien Pérolat', 'Mathieu Laurière', 'Matthieu Geist', 'Olivier Pietquin']
# title:   Approximate Fictitious Play for Mean Field Games
#
# PAPER http://arxiv.org/abs/1906.11228v2
# [Download]
# file:    Markus Wulfmeier et al. - Regularized Hierarchical Policies for Compositional Transfer in Robotics.pdf
# url:     http://arxiv.org/abs/1906.11228v2
# authors: ['Markus Wulfmeier', 'Abbas Abdolmaleki', 'Roland Hafner', 'Jost Tobias Springenberg', 'Michael Neunert', 'Tim Hertweck', 'Thomas Lampe', 'Noah Siegel', 'Nicolas Heess', 'Martin Riedmiller']
# title:   Regularized Hierarchical Policies for Compositional Transfer in Robotics
#
# PAPER http://arxiv.org/abs/1902.07685v2
# [Download]
# file:    Mohammad Gheshlaghi Azar et al. - World Discovery Models.pdf
# url:     http://arxiv.org/abs/1902.07685v2
# authors: ['Mohammad Gheshlaghi Azar', 'Bilal Piot', 'Bernardo Avila Pires', 'Jean-Bastian Grill', 'Florent Altché', 'Rémi Munos']
# title:   World Discovery Models
#
# PAPER http://arxiv.org/abs/1906.09831v1
# [Download]
# file:    Alexis Jacq et al. - Foolproof Cooperative Learning.pdf
# url:     http://arxiv.org/abs/1906.09831v1
# authors: ['Alexis Jacq', 'Julien Perolat', 'Matthieu Geist', 'Olivier Pietquin']
# title:   Foolproof Cooperative Learning
#
# PAPER http://arxiv.org/abs/1906.08663v1
# [Download]
# file:    Tom Everitt et al. - Modeling AGI Safety Frameworks with Causal Influence Diagrams.pdf
# url:     http://arxiv.org/abs/1906.08663v1
# authors: ['Tom Everitt', 'Ramana Kumar', 'Victoria Krakovna', 'Shane Legg']
# title:   Modeling AGI Safety Frameworks with Causal Influence Diagrams
#
# PAPER http://arxiv.org/abs/1906.07987v1
# [Download]
# file:    Hugo Penedones et al. - Adaptive Temporal-Difference Learning for Policy Evaluation with Per-State Uncertainty Estimates.pdf
# url:     http://arxiv.org/abs/1906.07987v1
# authors: ['Hugo Penedones', 'Carlos Riquelme', 'Damien Vincent', 'Hartmut Maennel', 'Timothy Mann', 'Andre Barreto', 'Sylvain Gelly', 'Gergely Neu']
# title:   Adaptive Temporal-Difference Learning for Policy Evaluation with Per-State Uncertainty Estimates
#
# PAPER http://arxiv.org/abs/1906.07516v1
# [Download]
# file:    Daniel J. Mankowitz et al. - Robust Reinforcement Learning for Continuous Control with Model Misspecification.pdf
# url:     http://arxiv.org/abs/1906.07516v1
# authors: ['Daniel J. Mankowitz', 'Nir Levine', 'Rae Jeong', 'Abbas Abdolmaleki', 'Jost Tobias Springenberg', 'Timothy Mann', 'Todd Hester', 'Martin Riedmiller']
# title:   Robust Reinforcement Learning for Continuous Control with Model Misspecification
#
# PAPER http://arxiv.org/abs/1906.06062v1
# [Download]
# file:    Guy Lorberbom et al. - Direct Policy Gradients_ Direct Optimization of Policies in Discrete Action Spaces.pdf
# url:     http://arxiv.org/abs/1906.06062v1
# authors: ['Guy Lorberbom', 'Chris J. Maddison', 'Nicolas Heess', 'Tamir Hazan', 'Daniel Tarlow']
# title:   Direct Policy Gradients: Direct Optimization of Policies in Discrete Action Spaces
#
# PAPER http://arxiv.org/abs/1906.02500v1
# [Download]
# file:    Alex Mott et al. - Towards Interpretable Reinforcement Learning Using Attention Augmented Agents.pdf
# url:     http://arxiv.org/abs/1906.02500v1
# authors: ['Alex Mott', 'Daniel Zoran', 'Mike Chrzanowski', 'Daan Wierstra', 'Danilo J. Rezende']
# title:   Towards Interpretable Reinforcement Learning Using Attention Augmented Agents
#
# PAPER http://arxiv.org/abs/1905.12941v2
# [Download]
# file:    Thomas Pierrot et al. - Learning Compositional Neural Programs with Recursive Tree Search and Planning.pdf
# url:     http://arxiv.org/abs/1905.12941v2
# authors: ['Thomas Pierrot', 'Guillaume Ligner', 'Scott Reed', 'Olivier Sigaud', 'Nicolas Perrin', 'Alexandre Laterre', 'David Kas', 'Karim Beguir', 'Nando de Freitas']
# title:   Learning Compositional Neural Programs with Recursive Tree Search and Planning
#
# PAPER http://arxiv.org/abs/1905.08188v1
# [Download]
# file:    Esther Derman et al. - A Bayesian Approach to Robust Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/1905.08188v1
# authors: ['Esther Derman', 'Daniel Mankowitz', 'Timothy Mann', 'Shie Mannor']
# title:   A Bayesian Approach to Robust Reinforcement Learning
#
# PAPER http://arxiv.org/abs/1905.06424v1
# [Download]
# file:    Jan Humplik et al. - Meta reinforcement learning as task inference.pdf
# url:     http://arxiv.org/abs/1905.06424v1
# authors: ['Jan Humplik', 'Alexandre Galashov', 'Leonard Hasenclever', 'Pedro A. Ortega', 'Yee Whye Teh', 'Nicolas Heess']
# title:   Meta reinforcement learning as task inference
#
# PAPER http://arxiv.org/abs/1905.02691v1
# [Download]
# file:    Patrick M. Pilarski et al. - Learned human-agent decision-making, communication and joint action in a virtual reality environment.pdf
# url:     http://arxiv.org/abs/1905.02691v1
# authors: ['Patrick M. Pilarski', 'Andrew Butcher', 'Michael Johanson', 'Matthew M. Botvinick', 'Andrew Bolt', 'Adam S. R. Parker']
# title:   Learned human-agent decision-making, communication and joint action in a virtual reality environment
#
# PAPER http://arxiv.org/abs/1811.11359v1
# [Download]
# file:    David Warde-Farley et al. - Unsupervised Control Through Non-Parametric Discriminative Rewards.pdf
# url:     http://arxiv.org/abs/1811.11359v1
# authors: ['David Warde-Farley', 'Tom Van de Wiele', 'Tejas Kulkarni', 'Catalin Ionescu', 'Steven Hansen', 'Volodymyr Mnih']
# title:   Unsupervised Control Through Non-Parametric Discriminative Rewards
#
# PAPER http://arxiv.org/abs/1905.01320v1
# [Download]
# file:    Neil C. Rabinowitz - Meta-learners' learning dynamics are unlike learners'.pdf
# url:     http://arxiv.org/abs/1905.01320v1
# authors: ['Neil C. Rabinowitz']
# title:   Meta-learners' learning dynamics are unlike learners'
#
# PAPER http://arxiv.org/abs/1904.12901v1
# [Download]
# file:    Gabriel Dulac-Arnold et al. - Challenges of Real-World Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/1904.12901v1
# authors: ['Gabriel Dulac-Arnold', 'Daniel Mankowitz', 'Todd Hester']
# title:   Challenges of Real-World Reinforcement Learning
#
# PAPER http://arxiv.org/abs/1904.11455v1
# [Download]
# file:    Tom Schaul et al. - Ray Interference_ a Source of Plateaus in Deep Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/1904.11455v1
# authors: ['Tom Schaul', 'Diana Borsa', 'Joseph Modayil', 'Razvan Pascanu']
# title:   Ray Interference: a Source of Plateaus in Deep Reinforcement Learning
#
# PAPER http://arxiv.org/abs/1903.08082v1
# [Download]
# file:    Tom Eccles et al. - Learning Reciprocity in Complex Sequential Social Dilemmas.pdf
# url:     http://arxiv.org/abs/1903.08082v1
# authors: ['Tom Eccles', 'Edward Hughes', 'János Kramár', 'Steven Wheelwright', 'Joel Z. Leibo']
# title:   Learning Reciprocity in Complex Sequential Social Dilemmas
#
# PAPER http://arxiv.org/abs/1903.07438v1
# [Download]
# file:    Dhruva Tirumala et al. - Exploiting Hierarchy for Learning and Transfer in KL-regularized RL.pdf
# url:     http://arxiv.org/abs/1903.07438v1
# authors: ['Dhruva Tirumala', 'Hyeonwoo Noh', 'Alexandre Galashov', 'Leonard Hasenclever', 'Arun Ahuja', 'Greg Wayne', 'Razvan Pascanu', 'Yee Whye Teh', 'Nicolas Heess']
# title:   Exploiting Hierarchy for Learning and Transfer in KL-regularized RL
#
# PAPER http://arxiv.org/abs/1903.05614v3
# [Download]
# file:    Edward Lockhart et al. - Computing Approximate Equilibria in Sequential Adversarial Games by Exploitability Descent.pdf
# url:     http://arxiv.org/abs/1903.05614v3
# authors: ['Edward Lockhart', 'Marc Lanctot', 'Julien Pérolat', 'Jean-Baptiste Lespiau', 'Dustin Morrill', 'Finbarr Timbers', 'Karl Tuyls']
# title:   Computing Approximate Equilibria in Sequential Adversarial Games by Exploitability Descent
#
# PAPER http://arxiv.org/abs/1806.01186v2
# [Download]
# file:    Victoria Krakovna et al. - Penalizing side effects using stepwise relative reachability.pdf
# ...
# url:     http://arxiv.org/abs/1804.01118v1
# authors: ['Yaroslav Ganin', 'Tejas Kulkarni', 'Igor Babuschkin', 'S. M. Ali Eslami', 'Oriol Vinyals']
# title:   Synthesizing Programs for Images using Reinforced Adversarial Learning
#
# PAPER http://arxiv.org/abs/1803.06376v1
# [Download]
# file:    Karl Tuyls et al. - A Generalised Method for Empirical Game Theoretic Analysis.pdf
# url:     http://arxiv.org/abs/1803.06376v1
# authors: ['Karl Tuyls', 'Julien Perolat', 'Marc Lanctot', 'Joel Z Leibo', 'Thore Graepel']
# title:   A Generalised Method for Empirical Game Theoretic Analysis
#
# PAPER http://arxiv.org/abs/1802.10567v1
# [Download]
# file:    Martin Riedmiller et al. - Learning by Playing - Solving Sparse Reward Tasks from Scratch.pdf
# url:     http://arxiv.org/abs/1802.10567v1
# authors: ['Martin Riedmiller', 'Roland Hafner', 'Thomas Lampe', 'Michael Neunert', 'Jonas Degrave', 'Tom Van de Wiele', 'Volodymyr Mnih', 'Nicolas Heess', 'Jost Tobias Springenberg']
# title:   Learning by Playing - Solving Sparse Reward Tasks from Scratch
#
# PAPER http://arxiv.org/abs/1802.08294v2
# [Download]
# file:    Daniel J. Mankowitz et al. - Unicorn_ Continual Learning with a Universal, Off-policy Agent.pdf
# url:     http://arxiv.org/abs/1802.08294v2
# authors: ['Daniel J. Mankowitz', 'Augustin Žídek', 'André Barreto', 'Dan Horgan', 'Matteo Hessel', 'John Quan', 'Junhyuk Oh', 'Hado van Hasselt', 'David Silver', 'Tom Schaul']
# title:   Unicorn: Continual Learning with a Universal, Off-policy Agent
#
# PAPER http://arxiv.org/abs/1802.04697v2
# [Download]
# file:    Arthur Guez et al. - Learning to Search with MCTSnets.pdf
# url:     http://arxiv.org/abs/1802.04697v2
# authors: ['Arthur Guez', 'Théophane Weber', 'Ioannis Antonoglou', 'Karen Simonyan', 'Oriol Vinyals', 'Daan Wierstra', 'Rémi Munos', 'David Silver']
# title:   Learning to Search with MCTSnets
#
# PAPER http://arxiv.org/abs/1802.03493v2
# [Download]
# file:    Mehrdad Farajtabar et al. - More Robust Doubly Robust Off-policy Evaluation.pdf
# url:     http://arxiv.org/abs/1802.03493v2
# authors: ['Mehrdad Farajtabar', 'Yinlam Chow', 'Mohammad Ghavamzadeh']
# title:   More Robust Doubly Robust Off-policy Evaluation
#
# PAPER http://arxiv.org/abs/1802.03006v1
# [Download]
# file:    Lars Buesing et al. - Learning and Querying Fast Generative Models for Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/1802.03006v1
# authors: ['Lars Buesing', 'Theophane Weber', 'Sebastien Racaniere', 'S. M. Ali Eslami', 'Danilo Rezende', 'David P. Reichert', 'Fabio Viola', 'Frederic Besse', 'Karol Gregor', 'Demis Hassabis', 'Daan Wierstra']
# title:   Learning and Querying Fast Generative Models for Reinforcement Learning
#
# PAPER http://arxiv.org/abs/1711.09883v2
# [Download]
# file:    Jan Leike et al. - AI Safety Gridworlds.pdf
# url:     http://arxiv.org/abs/1711.09883v2
# authors: ['Jan Leike', 'Miljan Martic', 'Victoria Krakovna', 'Pedro A. Ortega', 'Tom Everitt', 'Andrew Lefrancq', 'Laurent Orseau', 'Shane Legg']
# title:   AI Safety Gridworlds
#
# PAPER http://arxiv.org/abs/1711.00832v2
# [Download]
# file:    Marc Lanctot et al. - A Unified Game-Theoretic Approach to Multiagent Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/1711.00832v2
# authors: ['Marc Lanctot', 'Vinicius Zambaldi', 'Audrunas Gruslys', 'Angeliki Lazaridou', 'Karl Tuyls', 'Julien Perolat', 'David Silver', 'Thore Graepel']
# title:   A Unified Game-Theoretic Approach to Multiagent Reinforcement Learning
#
# PAPER http://arxiv.org/abs/1710.02298v1
# [Download]
# file:    Matteo Hessel et al. - Rainbow_ Combining Improvements in Deep Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/1710.02298v1
# authors: ['Matteo Hessel', 'Joseph Modayil', 'Hado van Hasselt', 'Tom Schaul', 'Georg Ostrovski', 'Will Dabney', 'Dan Horgan', 'Bilal Piot', 'Mohammad Azar', 'David Silver']
# title:   Rainbow: Combining Improvements in Deep Reinforcement Learning
#
# PAPER http://arxiv.org/abs/1707.08475v2
# [Download]
# file:    Irina Higgins et al. - DARLA_ Improving Zero-Shot Transfer in Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/1707.08475v2
# authors: ['Irina Higgins', 'Arka Pal', 'Andrei A. Rusu', 'Loic Matthey', 'Christopher P Burgess', 'Alexander Pritzel', 'Matthew Botvinick', 'Charles Blundell', 'Alexander Lerchner']
# title:   DARLA: Improving Zero-Shot Transfer in Reinforcement Learning
#
# PAPER http://arxiv.org/abs/1707.06600v2
# [Download]
# file:    Julien Perolat et al. - A multi-agent reinforcement learning model of common-pool resource appropriation.pdf
# url:     http://arxiv.org/abs/1707.06600v2
# authors: ['Julien Perolat', 'Joel Z. Leibo', 'Vinicius Zambaldi', 'Charles Beattie', 'Karl Tuyls', 'Thore Graepel']
# title:   A multi-agent reinforcement learning model of common-pool resource appropriation
#
# PAPER http://arxiv.org/abs/1707.04175v1
# [Download]
# file:    Yee Whye Teh et al. - Distral_ Robust Multitask Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/1707.04175v1
# authors: ['Yee Whye Teh', 'Victor Bapst', 'Wojciech Marian Czarnecki', 'John Quan', 'James Kirkpatrick', 'Raia Hadsell', 'Nicolas Heess', 'Razvan Pascanu']
# title:   Distral: Robust Multitask Reinforcement Learning
#
# PAPER http://arxiv.org/abs/1707.03300v1
# [Download]
# file:    Serkan Cabi et al. - The Intentional Unintentional Agent_ Learning to Solve Many Continuous Control Tasks Simultaneously.pdf
# url:     http://arxiv.org/abs/1707.03300v1
# authors: ['Serkan Cabi', 'Sergio Gómez Colmenarejo', 'Matthew W. Hoffman', 'Misha Denil', 'Ziyu Wang', 'Nando de Freitas']
# title:   The Intentional Unintentional Agent: Learning to Solve Many Continuous Control Tasks Simultaneously
#
# PAPER http://arxiv.org/abs/1706.10295v3
# [Download]
# file:    Meire Fortunato et al. - Noisy Networks for Exploration.pdf
# url:     http://arxiv.org/abs/1706.10295v3
# authors: ['Meire Fortunato', 'Mohammad Gheshlaghi Azar', 'Bilal Piot', 'Jacob Menick', 'Ian Osband', 'Alex Graves', 'Vlad Mnih', 'Remi Munos', 'Demis Hassabis', 'Olivier Pietquin', 'Charles Blundell', 'Shane Legg']
# title:   Noisy Networks for Exploration
#
# PAPER http://arxiv.org/abs/1706.05296v1
# [Download]
# file:    Peter Sunehag et al. - Value-Decomposition Networks For Cooperative Multi-Agent Learning.pdf
# url:     http://arxiv.org/abs/1706.05296v1
# authors: ['Peter Sunehag', 'Guy Lever', 'Audrunas Gruslys', 'Wojciech Marian Czarnecki', 'Vinicius Zambaldi', 'Max Jaderberg', 'Marc Lanctot', 'Nicolas Sonnerat', 'Joel Z. Leibo', 'Karl Tuyls', 'Thore Graepel']
# title:   Value-Decomposition Networks For Cooperative Multi-Agent Learning
#
# PAPER http://arxiv.org/abs/1705.09805v3
# [Download]
# file:    Rico Jonschkowski et al. - PVEs_ Position-Velocity Encoders for Unsupervised Learning of Structured State Representations.pdf
# url:     http://arxiv.org/abs/1705.09805v3
# authors: ['Rico Jonschkowski', 'Roland Hafner', 'Jonathan Scholz', 'Martin Riedmiller']
# title:   PVEs: Position-Velocity Encoders for Unsupervised Learning of Structured State Representations
#
# PAPER http://arxiv.org/abs/1705.08417v2
# [Download]
# file:    Tom Everitt et al. - Reinforcement Learning with a Corrupted Reward Channel.pdf
# url:     http://arxiv.org/abs/1705.08417v2
# authors: ['Tom Everitt', 'Victoria Krakovna', 'Laurent Orseau', 'Marcus Hutter', 'Shane Legg']
# title:   Reinforcement Learning with a Corrupted Reward Channel
#
# PAPER http://arxiv.org/abs/1704.02254v2
# [Download]
# file:    Silvia Chiappa et al. - Recurrent Environment Simulators.pdf
# url:     http://arxiv.org/abs/1704.02254v2
# authors: ['Silvia Chiappa', 'Sébastien Racaniere', 'Daan Wierstra', 'Shakir Mohamed']
# title:   Recurrent Environment Simulators
#
# PAPER http://arxiv.org/abs/1703.05423v1
# [Download]
# file:    Florian Strub et al. - End-to-end optimization of goal-driven and visually grounded dialogue systems.pdf
# url:     http://arxiv.org/abs/1703.05423v1
# authors: ['Florian Strub', 'Harm de Vries', 'Jeremie Mary', 'Bilal Piot', 'Aaron Courville', 'Olivier Pietquin']
# title:   End-to-end optimization of goal-driven and visually grounded dialogue systems
#
# PAPER http://arxiv.org/abs/1703.01988v1
# [Download]
# file:    Alexander Pritzel et al. - Neural Episodic Control.pdf
# url:     http://arxiv.org/abs/1703.01988v1
# authors: ['Alexander Pritzel', 'Benigno Uria', 'Sriram Srinivasan', 'Adrià Puigdomènech', 'Oriol Vinyals', 'Demis Hassabis', 'Daan Wierstra', 'Charles Blundell']
# title:   Neural Episodic Control
#
# PAPER http://arxiv.org/abs/1703.01161v2
# [Download]
# file:    Alexander Sasha Vezhnevets et al. - FeUdal Networks for Hierarchical Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/1703.01161v2
# authors: ['Alexander Sasha Vezhnevets', 'Simon Osindero', 'Tom Schaul', 'Nicolas Heess', 'Max Jaderberg', 'David Silver', 'Koray Kavukcuoglu']
# title:   FeUdal Networks for Hierarchical Reinforcement Learning
#
# PAPER http://arxiv.org/abs/1703.01310v2
# [Download]
# file:    Georg Ostrovski et al. - Count-Based Exploration with Neural Density Models.pdf
# url:     http://arxiv.org/abs/1703.01310v2
# authors: ['Georg Ostrovski', 'Marc G. Bellemare', 'Aaron van den Oord', 'Remi Munos']
# title:   Count-Based Exploration with Neural Density Models
#
# PAPER http://arxiv.org/abs/1606.08718v4
# [Download]
# file:    Julien Pérolat et al. - Learning Nash Equilibrium for General-Sum Markov Games from Batch Data.pdf
# url:     http://arxiv.org/abs/1606.08718v4
# authors: ['Julien Pérolat', 'Florian Strub', 'Bilal Piot', 'Olivier Pietquin']
# title:   Learning Nash Equilibrium for General-Sum Markov Games from Batch Data
#
# PAPER http://arxiv.org/abs/1611.03673v3
# [Download]
# file:    Piotr Mirowski et al. - Learning to Navigate in Complex Environments.pdf
# url:     http://arxiv.org/abs/1611.03673v3
# authors: ['Piotr Mirowski', 'Razvan Pascanu', 'Fabio Viola', 'Hubert Soyer', 'Andrew J. Ballard', 'Andrea Banino', 'Misha Denil', 'Ross Goroshin', 'Laurent Sifre', 'Koray Kavukcuoglu', 'Dharshan Kumaran', 'Raia Hadsell']
# title:   Learning to Navigate in Complex Environments
#
# PAPER http://arxiv.org/abs/1611.09100v1
# [Download]
# file:    Dani Yogatama et al. - Learning to Compose Words into Sentences with Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/1611.09100v1
# authors: ['Dani Yogatama', 'Phil Blunsom', 'Chris Dyer', 'Edward Grefenstette', 'Wang Ling']
# title:   Learning to Compose Words into Sentences with Reinforcement Learning
#
# PAPER http://arxiv.org/abs/1611.05763v3
# [Download]
# file:    Jane X Wang et al. - Learning to reinforcement learn.pdf
# url:     http://arxiv.org/abs/1611.05763v3
# authors: ['Jane X Wang', 'Zeb Kurth-Nelson', 'Dhruva Tirumala', 'Hubert Soyer', 'Joel Z Leibo', 'Remi Munos', 'Charles Blundell', 'Dharshan Kumaran', 'Matt Botvinick']
# title:   Learning to reinforcement learn
#
# PAPER http://arxiv.org/abs/1611.05397v1
# [Download]
# file:    Max Jaderberg et al. - Reinforcement Learning with Unsupervised Auxiliary Tasks.pdf
# url:     http://arxiv.org/abs/1611.05397v1
# authors: ['Max Jaderberg', 'Volodymyr Mnih', 'Wojciech Marian Czarnecki', 'Tom Schaul', 'Joel Z Leibo', 'David Silver', 'Koray Kavukcuoglu']
# title:   Reinforcement Learning with Unsupervised Auxiliary Tasks
#
# PAPER http://arxiv.org/abs/1611.01626v3
# [Download]
# file:    Brendan O'Donoghue et al. - Combining policy gradient and Q-learning.pdf
# url:     http://arxiv.org/abs/1611.01626v3
# authors: ["Brendan O'Donoghue", 'Remi Munos', 'Koray Kavukcuoglu', 'Volodymyr Mnih']
# title:   Combining policy gradient and Q-learning
#
# PAPER http://arxiv.org/abs/1610.04286v2
# [Download]
# file:    Andrei A. Rusu et al. - Sim-to-Real Robot Learning from Pixels with Progressive Nets.pdf
# url:     http://arxiv.org/abs/1610.04286v2
# authors: ['Andrei A. Rusu', 'Mel Vecerik', 'Thomas Rothörl', 'Nicolas Heess', 'Razvan Pascanu', 'Raia Hadsell']
# title:   Sim-to-Real Robot Learning from Pixels with Progressive Nets
#
# PAPER http://arxiv.org/abs/1610.01945v3
# [Download]
# file:    David Pfau et al. - Connecting Generative Adversarial Networks and Actor-Critic Methods.pdf
# url:     http://arxiv.org/abs/1610.01945v3
# authors: ['David Pfau', 'Oriol Vinyals']
# title:   Connecting Generative Adversarial Networks and Actor-Critic Methods
#
# PAPER http://arxiv.org/abs/1606.04671v4
# [Download]
# file:    Andrei A. Rusu et al. - Progressive Neural Networks.pdf
# url:     http://arxiv.org/abs/1606.04671v4
# authors: ['Andrei A. Rusu', 'Neil C. Rabinowitz', 'Guillaume Desjardins', 'Hubert Soyer', 'James Kirkpatrick', 'Koray Kavukcuoglu', 'Razvan Pascanu', 'Raia Hadsell']
# title:   Progressive Neural Networks
#
# PAPER http://arxiv.org/abs/1511.05952v3
# [Download]
# file:    Tom Schaul et al. - Prioritized Experience Replay.pdf
# url:     http://arxiv.org/abs/1511.05952v3
# authors: ['Tom Schaul', 'John Quan', 'Ioannis Antonoglou', 'David Silver']
# title:   Prioritized Experience Replay
#
# PAPER http://arxiv.org/abs/1606.05312v2
# [Download]
# file:    André Barreto et al. - Successor Features for Transfer in Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/1606.05312v2
# authors: ['André Barreto', 'Will Dabney', 'Rémi Munos', 'Jonathan J. Hunt', 'Tom Schaul', 'Hado van Hasselt', 'David Silver']
# title:   Successor Features for Transfer in Reinforcement Learning
#
# PAPER http://arxiv.org/abs/1606.04695v1
# [Download]
# file:    Alexander et al. - Strategic Attentive Writer for Learning Macro-Actions.pdf
# url:     http://arxiv.org/abs/1606.04695v1
# authors: ['Alexander', 'Vezhnevets', 'Volodymyr Mnih', 'John Agapiou', 'Simon Osindero', 'Alex Graves', 'Oriol Vinyals', 'Koray Kavukcuoglu']
# title:   Strategic Attentive Writer for Learning Macro-Actions
#
# PAPER http://arxiv.org/abs/1509.02971v2
# [Download]
# file:    Timothy P. Lillicrap et al. - Continuous control with deep reinforcement learning.pdf
# url:     http://arxiv.org/abs/1509.02971v2
# authors: ['Timothy P. Lillicrap', 'Jonathan J. Hunt', 'Alexander Pritzel', 'Nicolas Heess', 'Tom Erez', 'Yuval Tassa', 'David Silver', 'Daan Wierstra']
# title:   Continuous control with deep reinforcement learning
#
# PAPER http://arxiv.org/abs/1412.7755v2
# [Download]
# file:    Jimmy Ba et al. - Multiple Object Recognition with Visual Attention.pdf
# url:     http://arxiv.org/abs/1412.7755v2
# authors: ['Jimmy Ba', 'Volodymyr Mnih', 'Koray Kavukcuoglu']
# title:   Multiple Object Recognition with Visual Attention
#
# PAPER http://arxiv.org/abs/1507.04296v2
# [Download]
# file:    Arun Nair et al. - Massively Parallel Methods for Deep Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/1507.04296v2
# authors: ['Arun Nair', 'Praveen Srinivasan', 'Sam Blackwell', 'Cagdas Alcicek', 'Rory Fearon', 'Alessandro De Maria', 'Vedavyas Panneershelvam', 'Mustafa Suleyman', 'Charles Beattie', 'Stig Petersen', 'Shane Legg', 'Volodymyr Mnih', 'Koray Kavukcuoglu', 'David Silver']
# title:   Massively Parallel Methods for Deep Reinforcement Learning
#
# PAPER http://arxiv.org/abs/1307.3176v4
# [Download]
# file:    Nathaniel Korda et al. - Fast gradient descent for drifting least squares regression, with application to bandits.pdf
# url:     http://arxiv.org/abs/1307.3176v4
# authors: ['Nathaniel Korda', 'Prashanth L. A.', 'Rémi Munos']
# title:   Fast gradient descent for drifting least squares regression, with application to bandits
#
# PAPER http://arxiv.org/abs/1509.08731v1
# [Download]
# file:    Shakir Mohamed et al. - Variational Information Maximisation for Intrinsically Motivated Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/1509.08731v1
# authors: ['Shakir Mohamed', 'Danilo Jimenez Rezende']
# title:   Variational Information Maximisation for Intrinsically Motivated Reinforcement Learning
#
# PAPER http://arxiv.org/abs/1411.5326v1
# [Download]
# file:    Joel Veness et al. - Compress and Control.pdf
# url:     http://arxiv.org/abs/1411.5326v1
# authors: ['Joel Veness', 'Marc G. Bellemare', 'Marcus Hutter', 'Alvin Chua', 'Guillaume Desjardins']
# title:   Compress and Control
#
# PAPER http://arxiv.org/abs/1312.5602v1
# [Download]
# file:    Volodymyr Mnih et al. - Playing Atari with Deep Reinforcement Learning.pdf
# url:     http://arxiv.org/abs/1312.5602v1
# authors: ['Volodymyr Mnih', 'Koray Kavukcuoglu', 'David Silver', 'Alex Graves', 'Ioannis Antonoglou', 'Daan Wierstra', 'Martin Riedmiller']
# title:   Playing Atari with Deep Reinforcement Learning
